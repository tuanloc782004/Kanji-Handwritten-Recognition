# %% [markdown]
# # **🇯🇵 Kanji Handwritten Recognition - Interactive Demo (Gradio)**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1️⃣ CÀI ĐẶT THƯ VIỆN CẦN THIẾT

# %%
print("STEP 1: Installing Gradio...")
# !pip install -q gradio

print("✅ Gradio installed successfully.")
# Out:
# STEP 1: Installing Gradio...
# ✅ Gradio installed successfully.

# %% [markdown]
# # 2️⃣ THIẾT LẬP CẤU HÌNH VÀ TẢI ARTIFACTS

# %%
print("\nSTEP 2: Setting up Configuration and Loading Artifacts...")
import gradio as gr
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import transforms
from PIL import Image
import numpy as np
import json
from pathlib import Path

# --- Cấu hình (PHẢI TRÙNG KHỚP VỚI FILE HUẤN LUYỆN) ---
WORK_DIR = Path('/content/drive/MyDrive/kanji_handwritten_recognition')
MODEL_PATH = WORK_DIR / 'models' / 'best_model.pth'
IDX2CHAR_PATH = WORK_DIR / 'idx2char.json'
IMG_SIZE = 96  # Kích thước ảnh mà mô hình nhận đầu vào
DEVICE = torch.device('cpu') # Demo sẽ chạy trên CPU

# --- Tải file ánh xạ (mapping) ---
try:
    with open(IDX2CHAR_PATH, 'r', encoding='utf-8') as f:
        idx2char = json.load(f)
    # Chuyển key từ string về integer
    idx2char = {int(k): v for k, v in idx2char.items()}
    NUM_CLASSES = len(idx2char)
    print(f"✅ Loaded character map with {NUM_CLASSES} classes.")
except FileNotFoundError:
    raise FileNotFoundError(f"Could not find idx2char.json at {IDX2CHAR_PATH}. Please ensure the training pipeline ran successfully.")
# Out:
# STEP 2: Setting up Configuration and Loading Artifacts...
# ✅ Loaded character map with 93 classes.

# %% [markdown]
# # 3️⃣ ĐỊNH NGHĨA LẠI KIẾN TRÚC MÔ HÌNH

# %%
print("\nSTEP 3: Redefining the Model Architecture...")

def build_resnet18_grayscale(num_classes: int, dropout_rate: float = 0.5):
    """
    Hàm này PHẢI GIỐNG HỆT hàm đã dùng trong quá trình huấn luyện
    để đảm bảo kiến trúc khớp với trọng số đã lưu.
    """
    model = models.resnet18(weights=None)
    model.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
    num_features = model.fc.in_features
    model.fc = nn.Sequential(
        nn.Dropout(p=dropout_rate),
        nn.Linear(num_features, num_classes)
    )
    return model

# --- Tải mô hình và trọng số đã huấn luyện ---
try:
    model = build_resnet18_grayscale(num_classes=NUM_CLASSES).to(DEVICE)
    model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
    model.eval() # Rất quan trọng: Chuyển mô hình sang chế độ đánh giá
    print("✅ Model architecture defined and weights loaded successfully.")
except FileNotFoundError:
    raise FileNotFoundError(f"Could not find best_model.pth at {MODEL_PATH}. Please ensure the training pipeline ran successfully.")
# Out:
# STEP 3: Redefining the Model Architecture...
# ✅ Model architecture defined and weights loaded successfully.

# %% [markdown]
# # 4️⃣ ĐỊNH NGHĨA HÀM TIỀN XỬ LÝ VÀ DỰ ĐOÁN

# %%
print("\nSTEP 4: Defining Preprocessing and Prediction Functions...")

# --- Các phép biến đổi cho ảnh đầu vào (PHẢI GIỐNG HỆT eval_transforms) ---
preprocess_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

def predict(image: dict) -> dict:
    """
    Hàm nhận dictionary đầu vào từ Gradio, trích xuất ảnh,
    tiền xử lý và trả về dự đoán.
    """
    # Lấy mảng NumPy của ảnh từ dictionary
    # THAY ĐỔI CHÍNH LÀ ĐÂY
    drawing_data = image['composite']

    if drawing_data is None:
        return {}

    # Lật ngược màu sắc (chữ đen trên nền trắng -> chữ trắng trên nền đen)
    inverted_image = 255 - drawing_data

    # Chuyển mảng NumPy thành ảnh PIL và chuyển sang ảnh xám
    pil_image = Image.fromarray(inverted_image).convert('L')

    # Các bước còn lại giữ nguyên
    image_tensor = preprocess_transform(pil_image).unsqueeze(0).to(DEVICE)

    with torch.no_grad():
        logits = model(image_tensor)
        probabilities = torch.nn.functional.softmax(logits, dim=1)[0]

    top5_probs, top5_indices = torch.topk(probabilities, k=5)
    confidences = {idx2char[idx.item()]: prob.item() for idx, prob in zip(top5_indices, top5_probs)}

    return confidences

print("✅ Prediction function is ready.")
# Out:
# STEP 4: Defining Preprocessing and Prediction Functions...
# ✅ Prediction function is ready.

# %% [markdown]
# # 5️⃣ KHỞI TẠO VÀ CHẠY GIAO DIỆN GRADIO

# %%
print("\nSTEP 5: Launching the Gradio Interface...")
print("Please wait a moment for the Gradio link to appear...")

# Tạo giao diện
iface = gr.Interface(
    fn=predict,
    inputs=gr.Sketchpad(
        type="numpy",
        width=280,
        height=280,
        image_mode='RGB',
        label="Draw a Kanji Character"
    ),
    outputs=gr.Label(
        num_top_classes=5,
        label="Top 5 Predictions"
    ),
    live=True,
    title="🇯🇵 Kanji Handwriting Recognition Demo",
    description=(
        "Draw a single Kanji character in the box below using your mouse or finger. "
        "The model will predict the character in real-time. "
        "This demo uses a ResNet18 model trained on the kkanji2 dataset."
    )
)

iface.launch(debug=True, share=True)
# Out:
# STEP 5: Launching the Gradio Interface...
# Please wait a moment for the Gradio link to appear...
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://899ee56a8999c06073.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://899ee56a8999c06073.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# content_type multipart/form-data; boundary=----WebKitFormBoundaryp6SYCfejgqDMBgmL
# content_type multipart/form-data; boundary=----WebKitFormBoundaryeSOE2AJAjn4LEHDw
# content_type multipart/form-data; boundary=----WebKitFormBoundary09BBFdpIZRcy9yIo
# content_type multipart/form-data; boundary=----WebKitFormBoundaryLDy3E9MyFvP66KAD
# content_type multipart/form-data; boundary=----WebKitFormBoundarybhGTPRsWPMw9GKB8
# content_type multipart/form-data; boundary=----WebKitFormBoundaryPX6jNPHvljauwKrU
# content_type multipart/form-data; boundary=----WebKitFormBoundary7oAy6nbf8hBMFMFA
# content_type multipart/form-data; boundary=----WebKitFormBoundary4pPPKTEm67e5e4mg
# content_type multipart/form-data; boundary=----WebKitFormBoundaryL6P8HCABDBl4DBYb
# content_type multipart/form-data; boundary=----WebKitFormBoundaryo4dXtRiDgctKRMA4
# content_type multipart/form-data; boundary=----WebKitFormBoundaryt0t750OIT8FoV5DW
# content_type multipart/form-data; boundary=----WebKitFormBoundary8cvkIBCP8FwA0lTP
# content_type multipart/form-data; boundary=----WebKitFormBoundaryu5EFHt1urL6o1f80
# content_type multipart/form-data; boundary=----WebKitFormBoundaryhD1muu4mgBdEnwlz
# content_type multipart/form-data; boundary=----WebKitFormBoundary03Jf15UAofMjK0vF
# content_type multipart/form-data; boundary=----WebKitFormBoundaryqrqjn5QXHuyAOL32
# content_type multipart/form-data; boundary=----WebKitFormBoundary8OGxmBr5qAV7U1V6
# content_type multipart/form-data; boundary=----WebKitFormBoundaryPvGZxiSBwxA8eMbv
# content_type multipart/form-data; boundary=----WebKitFormBoundaryFD1AgGUOXD9zHAzj
# content_type multipart/form-data; boundary=----WebKitFormBoundaryzXieADatAxLdNV56
# content_type multipart/form-data; boundary=----WebKitFormBoundaryGGjwccZJM5T7A4xb
# content_type multipart/form-data; boundary=----WebKitFormBoundary63TjWuq7ze4dhziN
# content_type multipart/form-data; boundary=----WebKitFormBoundaryMUYgS89Vj9NvDi13
# content_type multipart/form-data; boundary=----WebKitFormBoundaryiD7oE4VXGs2R31s9
# content_type multipart/form-data; boundary=----WebKitFormBoundarySZKcNonaRPa6XBRy
# content_type multipart/form-data; boundary=----WebKitFormBoundarycv1icPbmZGHnyNVC
# content_type multipart/form-data; boundary=----WebKitFormBoundarySB0d6qhE5EY3tlet
# content_type multipart/form-data; boundary=----WebKitFormBoundarytXf5EKAhpxNMM9o9
# content_type multipart/form-data; boundary=----WebKitFormBoundaryLOTnzyJTOAReX0WA
# content_type multipart/form-data; boundary=----WebKitFormBoundarydogBzeQ3BllR6n8e
# content_type multipart/form-data; boundary=----WebKitFormBoundarye96F5sBAcxAfA8xC
# content_type multipart/form-data; boundary=----WebKitFormBoundarydGPhHL2530ZRb1Xd
# content_type multipart/form-data; boundary=----WebKitFormBoundaryimJUJpfL9D94HEBO
# content_type multipart/form-data; boundary=----WebKitFormBoundaryBbAItOnOba56BEH6
# content_type multipart/form-data; boundary=----WebKitFormBoundaryMqV8MNKBDDXtujUR
# content_type multipart/form-data; boundary=----WebKitFormBoundaryuuYnO7YSBdI8NIQG
# content_type multipart/form-data; boundary=----WebKitFormBoundarymQxIA0dD8C5ODsUE
# content_type multipart/form-data; boundary=----WebKitFormBoundarymDOCCBEbDmAzwY1a
# content_type multipart/form-data; boundary=----WebKitFormBoundaryMJkHMF9sAHBk9qAo
# content_type multipart/form-data; boundary=----WebKitFormBoundaryNSB0e7Z17bXBQTCA
# content_type multipart/form-data; boundary=----WebKitFormBoundaryb3aI8hb2MTVbAInE
# content_type multipart/form-data; boundary=----WebKitFormBoundary9x66RrUxoiwZJkn1
# content_type multipart/form-data; boundary=----WebKitFormBoundarycB6I3bj0NDqLHTTN
# content_type multipart/form-data; boundary=----WebKitFormBoundaryOrvOLeFLcsss9Ars
# content_type multipart/form-data; boundary=----WebKitFormBoundaryjictWPWpVdYs8gkd
# content_type multipart/form-data; boundary=----WebKitFormBoundaryBd8OMNJuSHBaj41M
# content_type multipart/form-data; boundary=----WebKitFormBoundaryqtazeGahaazQAuW9
# content_type multipart/form-data; boundary=----WebKitFormBoundaryiFpGN8Tt7X04ZL2W
# content_type multipart/form-data; boundary=----WebKitFormBoundaryFIe0kYplR60eirwb
# content_type multipart/form-data; boundary=----WebKitFormBoundary9Fs4c0AlAKcHlBMk
# content_type multipart/form-data; boundary=----WebKitFormBoundaryZVAZKgx0yM1ufVAQ
# content_type multipart/form-data; boundary=----WebKitFormBoundaryfKpcpx5fQ3JmAvwS
# content_type multipart/form-data; boundary=----WebKitFormBoundaryxBXP63YND38MSKHv
# content_type multipart/form-data; boundary=----WebKitFormBoundaryq2dYjbetoYGjGOes
# content_type multipart/form-data; boundary=----WebKitFormBoundaryBXNjZYejS3r5XKix
# content_type multipart/form-data; boundary=----WebKitFormBoundaryAIM3XddCAUA2DSNL
# content_type multipart/form-data; boundary=----WebKitFormBoundaryRToOyBxQmUqM8FpI
# content_type multipart/form-data; boundary=----WebKitFormBoundarymWP7P7xBEBuP4pG9
# content_type multipart/form-data; boundary=----WebKitFormBoundary7eC6Ms4lsD5ulf6L
# content_type multipart/form-data; boundary=----WebKitFormBoundaryXk5xckDB2SRTAfV6
# content_type multipart/form-data; boundary=----WebKitFormBoundaryOG7pa7wXrg7A1Jyc
# content_type multipart/form-data; boundary=----WebKitFormBoundary9z7ttzL1jzR9dAUo
# content_type multipart/form-data; boundary=----WebKitFormBoundaryM5AeMUvc04qSdMSW
# content_type multipart/form-data; boundary=----WebKitFormBoundary9wVn7nqUxGqLo2NB
# content_type multipart/form-data; boundary=----WebKitFormBoundaryyBVWcY2jBVb2DdM8
# content_type multipart/form-data; boundary=----WebKitFormBoundary4oeraIrG6PBZ3IT0
# content_type multipart/form-data; boundary=----WebKitFormBoundaryVGlzKYIer8UKF2ie
# content_type multipart/form-data; boundary=----WebKitFormBoundarydC52CAY7AWInbPGl
# content_type multipart/form-data; boundary=----WebKitFormBoundaryPnvtEAezrYwMgpKj
# content_type multipart/form-data; boundary=----WebKitFormBoundaryf9DotQicAN289k86
# content_type multipart/form-data; boundary=----WebKitFormBoundarya7KDaEArVtdat9Js
# content_type multipart/form-data; boundary=----WebKitFormBoundarySp4kwJGNj2ebAKhM
# content_type multipart/form-data; boundary=----WebKitFormBoundarymVWOknGA2P3pkawm
# content_type multipart/form-data; boundary=----WebKitFormBoundaryWAohLWiOF9goQMdc
# content_type multipart/form-data; boundary=----WebKitFormBoundaryuLu4ntlGVG1gAbKs
# content_type multipart/form-data; boundary=----WebKitFormBoundaryd0BiiWrH8O1B4wCC
# content_type multipart/form-data; boundary=----WebKitFormBoundaryMIA0HZhKQktrVTH0
# content_type multipart/form-data; boundary=----WebKitFormBoundaryRKtPDR70ak9bNqqZ
# content_type multipart/form-data; boundary=----WebKitFormBoundaryL7BcQX1SiBz5q6AJ
# content_type multipart/form-data; boundary=----WebKitFormBoundaryQm33I2340kRnHRTB
# content_type multipart/form-data; boundary=----WebKitFormBoundaryvf1jRcooF080ptIA
# content_type multipart/form-data; boundary=----WebKitFormBoundaryLNxxjK77857VkUnm
# content_type multipart/form-data; boundary=----WebKitFormBoundaryMhT6YAqEYCfs8XzM
# content_type multipart/form-data; boundary=----WebKitFormBoundarylM8XTBE6L05sRioh
# content_type multipart/form-data; boundary=----WebKitFormBoundary6Y0TLrWj2Hz5sTSB
# content_type multipart/form-data; boundary=----WebKitFormBoundarySrJ9IqhTq6AZzclP
# content_type multipart/form-data; boundary=----WebKitFormBoundaryIEOMsy1vWYARAup0
# content_type multipart/form-data; boundary=----WebKitFormBoundaryWAPtMF5W2PJDKFsz
# content_type multipart/form-data; boundary=----WebKitFormBoundaryiBYAQfttkixL2G4j
# content_type multipart/form-data; boundary=----WebKitFormBoundary6SLgRDbNhYyL6yno
# content_type multipart/form-data; boundary=----WebKitFormBoundary0WdGTKKKTFSVGFyp
# content_type multipart/form-data; boundary=----WebKitFormBoundaryuEGbAeUE3xNNqKZF
# content_type multipart/form-data; boundary=----WebKitFormBoundaryGLneHVfAKLirFRqP
# content_type multipart/form-data; boundary=----WebKitFormBoundaryPE1DeT3lUrEOir66
# content_type multipart/form-data; boundary=----WebKitFormBoundaryOfJlADYTgjVj1FEH
# content_type multipart/form-data; boundary=----WebKitFormBoundary89V8WFWt501evERO
# content_type multipart/form-data; boundary=----WebKitFormBoundaryHXlOLf6XBaShWGL7
# content_type multipart/form-data; boundary=----WebKitFormBoundaryBCqKZopph2URH5M5
# content_type multipart/form-data; boundary=----WebKitFormBoundary5Aj4otFh3YEGSYaM
# content_type multipart/form-data; boundary=----WebKitFormBoundary9rACoWvBJEQ2Rna9
# content_type multipart/form-data; boundary=----WebKitFormBoundarymQhhOAHFTAc9hqlf
# content_type multipart/form-data; boundary=----WebKitFormBoundaryqvbGT69iPWlukHQY
# content_type multipart/form-data; boundary=----WebKitFormBoundaryvahoX6UbUHKfQq9H
# content_type multipart/form-data; boundary=----WebKitFormBoundaryhH6Wvlferb4voEOz
# content_type multipart/form-data; boundary=----WebKitFormBoundarylqvMNGrA4MWrycVS
# content_type multipart/form-data; boundary=----WebKitFormBoundaryvmKrkRGi8iogcB1i
# content_type multipart/form-data; boundary=----WebKitFormBoundaryqHAqnOd4gVTCs0Y3
# content_type multipart/form-data; boundary=----WebKitFormBoundaryECdjBjVlufTw4yBB
# content_type multipart/form-data; boundary=----WebKitFormBoundaryZCgiEZ8z36RlLDsj
# content_type multipart/form-data; boundary=----WebKitFormBoundaryc8I1b5Ye5PY72xIU
# content_type multipart/form-data; boundary=----WebKitFormBoundaryAJSJgOb1fK3ORl7q
# content_type multipart/form-data; boundary=----WebKitFormBoundaryILaEP9j8e7D7JUR1
# content_type multipart/form-data; boundary=----WebKitFormBoundarysenCpBZarLqEw1vc
# content_type multipart/form-data; boundary=----WebKitFormBoundaryNc02HNzE7tKvo6Ex
# content_type multipart/form-data; boundary=----WebKitFormBoundaryFbuS78ydHnD5upNs
# content_type multipart/form-data; boundary=----WebKitFormBoundarymAYU5od7nhAhzfrt
# content_type multipart/form-data; boundary=----WebKitFormBoundaryvjsSJAeWIobUHybh
# content_type multipart/form-data; boundary=----WebKitFormBoundaryy9g44DsOQidpxcH4
# content_type multipart/form-data; boundary=----WebKitFormBoundarypr1ShJLg5u8pttBP
# content_type multipart/form-data; boundary=----WebKitFormBoundaryzuA4Atc0s5Y0Fb1F
# content_type multipart/form-data; boundary=----WebKitFormBoundaryX5wefLfB4R4DVmrv
# content_type multipart/form-data; boundary=----WebKitFormBoundarylr4BJ7Oj58QQ4fwK
# content_type multipart/form-data; boundary=----WebKitFormBoundaryTRohz58ffbYc6uM1
# content_type multipart/form-data; boundary=----WebKitFormBoundaryNVwLBONeARFAwmAl
# content_type multipart/form-data; boundary=----WebKitFormBoundaryzuORCk8iZyaJHBLs
# content_type multipart/form-data; boundary=----WebKitFormBoundaryMQlqC3dOBMD72WOP
# content_type multipart/form-data; boundary=----WebKitFormBoundaryBC8PVAXqXXLBBeNY
# content_type multipart/form-data; boundary=----WebKitFormBoundaryPUu1VSKfRVaQlQqA
# content_type multipart/form-data; boundary=----WebKitFormBoundaryrZVsTFHedv95PYqp
# content_type multipart/form-data; boundary=----WebKitFormBoundaryBys2p72qDOXjeSNJ
# content_type multipart/form-data; boundary=----WebKitFormBoundaryLfwNs1wNrns0rVBo
# content_type multipart/form-data; boundary=----WebKitFormBoundarygJeArxKjAfCPOPAl
# content_type multipart/form-data; boundary=----WebKitFormBoundaryfeTVQQT0cYWMoyZQ
# content_type multipart/form-data; boundary=----WebKitFormBoundaryvq67QbYi2xdM7ORk
# content_type multipart/form-data; boundary=----WebKitFormBoundaryylH91T38w4adAa45
# content_type multipart/form-data; boundary=----WebKitFormBoundary9yJTqxZ41lJGBs7E
# content_type multipart/form-data; boundary=----WebKitFormBoundaryhC4a37yFG7bNWnuv
# content_type multipart/form-data; boundary=----WebKitFormBoundarydZJIZwBEFXa0b1lB
# content_type multipart/form-data; boundary=----WebKitFormBoundary8CkDEPwYnN28qHEi
# content_type multipart/form-data; boundary=----WebKitFormBoundaryg1hLB6AM0RsGV6kW
# content_type multipart/form-data; boundary=----WebKitFormBoundarynB3Zi3tKiZ53ig3H
# content_type multipart/form-data; boundary=----WebKitFormBoundary6rLk7Bj1jv7Hgprc
# content_type multipart/form-data; boundary=----WebKitFormBoundaryWdlBiLbSxVMtWjjZ
# content_type multipart/form-data; boundary=----WebKitFormBoundary7B4e8I0qGm2YmqMh
# content_type multipart/form-data; boundary=----WebKitFormBoundarykTxWgoGD3ruZ9DJ1
# content_type multipart/form-data; boundary=----WebKitFormBoundaryHgLAG8ArNabsZ5PA
# content_type multipart/form-data; boundary=----WebKitFormBoundaryiYTvFzMnXA2n6DAa
# content_type multipart/form-data; boundary=----WebKitFormBoundaryswiMkS0B0gkzBsuI
# content_type multipart/form-data; boundary=----WebKitFormBoundaryEyxGVWrwF2f058Dx
# content_type multipart/form-data; boundary=----WebKitFormBoundaryU3T1qqcW9Vd6MybO
# content_type multipart/form-data; boundary=----WebKitFormBoundaryGYEr2e88sNopYWpQ
# content_type multipart/form-data; boundary=----WebKitFormBoundary4lYw3u8XOX2VTqUD
# content_type multipart/form-data; boundary=----WebKitFormBoundaryfgc1sWE03jjQ766a
# content_type multipart/form-data; boundary=----WebKitFormBoundaryvtXZBih4uIYmFB3E
# content_type multipart/form-data; boundary=----WebKitFormBoundary0UH2dsGN43GIkk8r
# content_type multipart/form-data; boundary=----WebKitFormBoundaryrQdyFE8mfOEc9kL3
# content_type multipart/form-data; boundary=----WebKitFormBoundaryB8YMdcprkG4QoVSv
# content_type multipart/form-data; boundary=----WebKitFormBoundaryUGG3MB3cDs1eBdMw
# content_type multipart/form-data; boundary=----WebKitFormBoundarypdzJV5q4G0tzAdOx
# content_type multipart/form-data; boundary=----WebKitFormBoundaryw8TDQ11ngzIa1U13
# content_type multipart/form-data; boundary=----WebKitFormBoundaryOXfVxBeLBjb8fEs9
# content_type multipart/form-data; boundary=----WebKitFormBoundaryHiouuNM5AYU2ouKd
# content_type multipart/form-data; boundary=----WebKitFormBoundaryFlafuDg5goxHXPDp
# content_type multipart/form-data; boundary=----WebKitFormBoundaryfdwkBIUlPBtoI50H
# content_type multipart/form-data; boundary=----WebKitFormBoundaryN3QjBMnhzjNrLKYC
# content_type multipart/form-data; boundary=----WebKitFormBoundaryoWdSULLiHWJdaTAK
# content_type multipart/form-data; boundary=----WebKitFormBoundaryoH44DofxJNgqHOBG
# content_type multipart/form-data; boundary=----WebKitFormBoundary2ZBIgtXkwlcDOVPx
# content_type multipart/form-data; boundary=----WebKitFormBoundaryA13hIHyZ3j05xjCL
# content_type multipart/form-data; boundary=----WebKitFormBoundaryRRsNAHvIzhz7F8v3
# content_type multipart/form-data; boundary=----WebKitFormBoundaryvoZexhKkl4DqYm3P
# content_type multipart/form-data; boundary=----WebKitFormBoundary4rJrfbZYUY0bBDbH
# content_type multipart/form-data; boundary=----WebKitFormBoundaryMAUMjafyyhCrSa3L
# content_type multipart/form-data; boundary=----WebKitFormBoundaryPO1YPG2ujLL01ICB
# content_type multipart/form-data; boundary=----WebKitFormBoundaryspInuyOZEQ2nxsUB
# content_type multipart/form-data; boundary=----WebKitFormBoundaryGjhIA8rZ9r3NtyK2
# content_type multipart/form-data; boundary=----WebKitFormBoundaryQJe0YK7911SieBoB
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://899ee56a8999c06073.gradio.live
